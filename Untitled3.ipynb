# %%
print("""
```To Do List```
by Hadita Maulana\n""")
tasks = []
def add_tugas(tugas):
    tasks.append(tugas)

def view_tugas():
    for i, tugas in enumerate(tasks):
        print(f"{i+1}. {tugas}")

def remove_tugas(index):
    del tasks[index]
    
def mark_tugas_complete(index):
    tasks[index] = 'X ' + tasks[index]

def main():
    print("Selamat Datang Di Dalam List Kamu!")
    while True:
        print("Apa Yang Ingin Anda Lakukan?")
        print("1. Tambahkan Tugas")
        print("2. Lihat Semua Tugas")
        print("3. Hapus Tugas")
        print("4. Tandai Tugas Yang Sudah Selesai")
        print("5. Quit")
        pilihan = int(input("Pilihan Kamu: "))
        if pilihan == 1:
            tugas = input("Masukkan Tugas: ")
            add_tugas(tugas)
        elif pilihan == 2:
            view_tugas()
        elif pilihan == 3:
            index = int(input("Masukkan nomor Tugas: "))
            remove_tugas(index)
        elif pilihan == 4:
            index = int(input("Masukkan nomor Tugas: "))
            mark_tugas_complete(index)
        elif pilihan == 5:      
            break
        else:
            
            print("ERROR,Anda Kurang Beruntung Coba Lagi.")

        
        print()
main()
# Out:
# ```To Do List```
# by Hadita Maulana
#
# Selamat Datang Di Dalam List Kamu!
# Apa Yang Ingin Anda Lakukan?
# 1. Tambahkan Tugas
# 2. Lihat Semua Tugas
# 3. Hapus Tugas
# 4. Tandai Tugas Yang Sudah Selesai
# 5. Quit
# Pilihan Kamu: 1
# Masukkan Tugas: tugas matematika diskrit
#
# Apa Yang Ingin Anda Lakukan?
# 1. Tambahkan Tugas
# 2. Lihat Semua Tugas
# 3. Hapus Tugas
# 4. Tandai Tugas Yang Sudah Selesai
# 5. Quit
# Pilihan Kamu: 1
# Masukkan Tugas: tugas dasar pemrograman
#
# Apa Yang Ingin Anda Lakukan?
# 1. Tambahkan Tugas
# 2. Lihat Semua Tugas
# 3. Hapus Tugas
# 4. Tandai Tugas Yang Sudah Selesai
# 5. Quit
# Pilihan Kamu: 1
# Masukkan Tugas: tugas aljabar
#
# Apa Yang Ingin Anda Lakukan?
# 1. Tambahkan Tugas
# 2. Lihat Semua Tugas
# 3. Hapus Tugas
# 4. Tandai Tugas Yang Sudah Selesai
# 5. Quit
# Pilihan Kamu: 1
